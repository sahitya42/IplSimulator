# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from math import sqrt
import pandas as pd
import matplotlib.pyplot as plt

df_bowler = pd.read_csv('batting.csv', encoding='utf-8')
df_bowler = df_bowler[['Ave', 'SR']]
print(df_bowler.columns.values)
df_bowler.isnull().values.any()

#df_bowler.to_csv('stat_bat.csv' , sep = ',')

mms = MinMaxScaler()
mms.fit(df_bowler)
dft = mms.transform(df_bowler)

Sum_of_squared_distances_bwl = []
K = range(1,30)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(dft)
    Sum_of_squared_distances_bwl.append(km.inertia_)
print(Sum_of_squared_distances_bwl)
print(len(Sum_of_squared_distances_bwl))


plt.plot(K, Sum_of_squared_distances_bwl, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
#plt.rcParams['figure.figsize']=[15, 11]
plt.show()
# Out:
# ['Ave' 'SR']
# [36.476161177139566, 15.616409924079367, 9.34915463374555, 6.834526204960797, 5.314193093710743, 4.35088608335806, 3.699073932154013, 3.167727168614245, 2.71720843653043, 2.4769119742494374, 2.2926816293238104, 2.0677203100509574, 1.86046574273242, 1.713648728958709, 1.6041386256015973, 1.5031777330879827, 1.4442477111085965, 1.3116321020121133, 1.2592805191055105, 1.1723759958589148, 1.0873023175844907, 1.0119803373872132, 0.9557195780562807, 0.9217563841299485, 0.8652056118094807, 0.8323616616582754, 0.7934077781271552, 0.727593895398838, 0.6918412443687438]
# 29
